# %%
# %pip install matplotlib
# %pip install numpy
# %pip install notebook
# %pip install tensorflow-addons
# %pip install tensorflow-model-optimization
# %pip install tensorflow==2.17.0
# %pip install keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/idrone2/.local/lib/python3.11/site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/idrone2/.local/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/idrone2/.local/lib/python3.11/site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: notebook in /home/idrone2/.local/lib/python3.11/site-packages (7.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/idrone2/.local/lib/python3.11/site-packages (from notebook) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/idrone2/.local/lib/python3.11/site-packages (from notebook) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /home/idrone2/.local/lib/python3.11/site-packages (from notebook) (4.2.4)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/idrone2/.local/lib/python3.11/site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /home/idrone2/.local/lib/python3.11/site-packages (from notebook) (6.4.1)
# Requirement already satisfied: anyio>=3.1.0 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (24.1)
# Requirement already satisfied: prometheus-client>=0.9 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.20.0)
# Requirement already satisfied: pyzmq>=24 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (26.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (2.2.5)
# Requirement already satisfied: setuptools>=40.1.0 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (70.1.0)
# Requirement already satisfied: babel>=2.10 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /home/idrone2/.local/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /home/idrone2/.local/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/idrone2/.local/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: certifi in /home/idrone2/.local/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /home/idrone2/.local/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/idrone2/.local/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in /home/idrone2/.local/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/idrone2/.local/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (1.8.5)
# Requirement already satisfied: ipython>=7.23.1 in /home/idrone2/.local/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (8.26.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/idrone2/.local/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/idrone2/.local/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (1.6.0)
# Requirement already satisfied: psutil in /home/idrone2/.local/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/idrone2/.local/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /home/idrone2/.local/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/idrone2/.local/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/idrone2/.local/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/idrone2/.local/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.2.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/idrone2/.local/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/idrone2/.local/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/idrone2/.local/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.1.0)
# Requirement already satisfied: defusedxml in /home/idrone2/.local/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/idrone2/.local/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/idrone2/.local/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/idrone2/.local/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/idrone2/.local/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /home/idrone2/.local/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.18.0)
# Requirement already satisfied: tinycss2 in /home/idrone2/.local/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/idrone2/.local/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/idrone2/.local/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/idrone2/.local/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (2.2.2)
# Requirement already satisfied: ptyprocess in /home/idrone2/.local/lib/python3.11/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook) (0.7.0)
# Requirement already satisfied: six>=1.9.0 in /home/idrone2/.local/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.16.0)
# Requirement already satisfied: webencodings in /home/idrone2/.local/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: decorator in /home/idrone2/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/idrone2/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/idrone2/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (3.0.47)
# Requirement already satisfied: stack-data in /home/idrone2/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.6.3)
# Requirement already satisfied: typing-extensions>=4.6 in /home/idrone2/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /home/idrone2/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (4.9.0)
# Requirement already satisfied: fqdn in /home/idrone2/.local/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in /home/idrone2/.local/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/idrone2/.local/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (3.0.0)
# Requirement already satisfied: uri-template in /home/idrone2/.local/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/idrone2/.local/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/idrone2/.local/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /home/idrone2/.local/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.5)
# Requirement already satisfied: pycparser in /home/idrone2/.local/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/idrone2/.local/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.8.4)
# Requirement already satisfied: wcwidth in /home/idrone2/.local/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in /home/idrone2/.local/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in /home/idrone2/.local/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/idrone2/.local/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (2.4.1)
# Requirement already satisfied: pure-eval in /home/idrone2/.local/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.2.3)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/idrone2/.local/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.9.0.20240316)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-addons in /home/idrone2/.local/lib/python3.11/site-packages (0.23.0)
# Requirement already satisfied: packaging in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow-addons) (24.1)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow-addons) (2.13.3)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-model-optimization in /home/idrone2/.local/lib/python3.11/site-packages (0.8.0)
# Requirement already satisfied: absl-py~=1.2 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow-model-optimization) (1.4.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow-model-optimization) (0.1.8)
# Requirement already satisfied: numpy~=1.23 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow-model-optimization) (1.26.4)
# Requirement already satisfied: six~=1.14 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow-model-optimization) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow==2.17.0 in /home/idrone2/.local/lib/python3.11/site-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (3.3.0)
# Requirement already satisfied: packaging in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (2.32.3)
# Requirement already satisfied: setuptools in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (70.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (1.65.4)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorflow==2.17.0) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/idrone2/.local/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow==2.17.0) (0.43.0)
# Requirement already satisfied: rich in /home/idrone2/.local/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow==2.17.0) (13.7.1)
# Requirement already satisfied: namex in /home/idrone2/.local/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow==2.17.0) (0.0.8)
# Requirement already satisfied: optree in /home/idrone2/.local/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow==2.17.0) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/idrone2/.local/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/idrone2/.local/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/idrone2/.local/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/idrone2/.local/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/idrone2/.local/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/idrone2/.local/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow==2.17.0) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/idrone2/.local/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow==2.17.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/idrone2/.local/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow==2.17.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/idrone2/.local/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow==2.17.0) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in /home/idrone2/.local/lib/python3.11/site-packages (3.5.0)
# Requirement already satisfied: absl-py in /home/idrone2/.local/lib/python3.11/site-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /home/idrone2/.local/lib/python3.11/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /home/idrone2/.local/lib/python3.11/site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in /home/idrone2/.local/lib/python3.11/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /home/idrone2/.local/lib/python3.11/site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /home/idrone2/.local/lib/python3.11/site-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /home/idrone2/.local/lib/python3.11/site-packages (from keras) (0.4.0)
# Requirement already satisfied: packaging in /home/idrone2/.local/lib/python3.11/site-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/idrone2/.local/lib/python3.11/site-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/idrone2/.local/lib/python3.11/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/idrone2/.local/lib/python3.11/site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/idrone2/.local/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/idrone2/.local/lib/python3.11/site-packages (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 128
CHANNELS=3
EPOCHS=100

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/home/idrone2/Desktop/SIH LEAF/training/sih_data_pest",
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 16317 files belonging to 22 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Cotton Aphids',
#  'Cotton Army worm',
#  'Cotton Bacterial blight',
#  'Cotton Powdery mildew',
#  'Cotton Target spot',
#  'Healthy Cotton',
#  'Healthy Potato Leaf',
#  'Healthy Sugarcane Leaf',
#  'Potato Leaf Bacteria',
#  'Potato Leaf Fungi',
#  'Potato Leaf Nematode',
#  'Potato Leaf Pest',
#  'Potato Leaf Phytopthora',
#  'Potato Leaf Virus',
#  'Rice Leaf Bacterialblight',
#  'Rice Leaf Blast',
#  'Rice Leaf Brownspot',
#  'Rice Leaf Tungro',
#  'Sugarcane Leaf Mosaic',
#  'Sugarcane Leaf RedRot',
#  'Sugarcane Leaf Rust',
#  'Sugarcane Leaf Yellow']

# %%
n_of_classes=len(class_names)
print(len(class_names))
# Out:
# 22

# %%
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (32, 128, 128, 3)
# [17  0 14 14 12  0 13 21  4  4  9  1  2 16 15  2  8 16 16 12  9 20 19  7
#   4  1  7 17  0 20 15  4]

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1

    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
len(val_ds)
len(test_ds)
# Out:
# 51

# %%
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  tf.keras.layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  tf.keras.layers.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal_and_vertical"),
  tf.keras.layers.RandomRotation(0.2),
])

# %%
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
from tensorflow.keras import layers, models

input_shape = (IMAGE_SIZE, IMAGE_SIZE, CHANNELS)  
n_classes = n_of_classes

model = models.Sequential([
    # First convolutional block
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Second convolutional block
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Third convolutional block
    layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Fourth convolutional block
    layers.Conv2D(256, kernel_size=(3, 3), activation='relu'),
    layers.Conv2D(256, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

   

    # Flatten and fully connected layers
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(n_classes, activation='softmax'),
])

# %%
model.summary()
# Out:
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_64 (Conv2D)              │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_65 (Conv2D)              │ (None, 124, 124, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_37 (MaxPooling2D) │ (None, 62, 62, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d
100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.8655 - loss: 0.4046 - val_accuracy: 0.8107 - val_loss: 0.6045
# Epoch 87/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.8524 - loss: 0.4372 - val_accuracy: 0.8370 - val_loss: 0.5663
# Epoch 88/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.8420 - loss: 0.4720 - val_accuracy: 0.8211 - val_loss: 0.5965
# Epoch 89/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.8524 - loss: 0.4422 - val_accuracy: 0.8419 - val_loss: 0.5307
# Epoch 90/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.8564 - loss: 0.4316 - val_accuracy: 0.8327 - val_loss: 0.5501
# Epoch 91/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.8538 - loss: 0.4444 - val_accuracy: 0.8327 - val_loss: 0.5110
# Epoch 92/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.8480 - loss: 0.4810 - val_accuracy: 0.8474 - val_loss: 0.4304
# Epoch 93/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.8690 - loss: 0.3982 - val_accuracy: 0.7770 - val_loss: 0.7478
# Epoch 94/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.8631 - loss: 0.4262 - val_accuracy: 0.7702 - val_loss: 0.7221
# Epoch 95/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.8515 - loss: 0.4513 - val_accuracy: 0.8064 - val_loss: 0.6198
# Epoch 96/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.8590 - loss: 0.4079 - val_accuracy: 0.8211 - val_loss: 0.6280
# Epoch 97/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.8443 - loss: 0.4885 - val_accuracy: 0.8364 - val_loss: 0.5008
# Epoch 98/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.7841 - loss: 0.8441 - val_accuracy: 0.8309 - val_loss: 0.5500
# Epoch 99/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.8639 - loss: 0.4206 - val_accuracy: 0.8373 - val_loss: 0.5581
# Epoch 100/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.8697 - loss: 0.3787 - val_accuracy: 0.8376 - val_loss: 0.5194

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Rice Leaf Brownspot
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# predicted label: Rice Leaf Brownspot

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(20, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))

        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import tensorflow as tf

# Function to get predictions and true labels
def get_predictions_and_labels(model, test_ds):
  all_preds = []
  all_labels = []
  for images, labels in test_ds:
    preds = model.predict(images)
    all_preds.extend(np.argmax(preds, axis=1))
    all_labels.extend(labels.numpy())
  return np.array(all_preds), np.array(all_labels)

# Get predictions and labels
y_pred, y_true = get_predictions_and_labels(model, test_ds)

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Create a ConfusionMatrixDisplay object
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)

# Plot the confusion matrix
plt.figure(figsize=(50, 50))  # Further adjusted figure size
disp.plot(cmap=plt.cm.Blues)

# Rotate x-axis labels for vertical display 
plt.xticks(rotation=90) 

# Adjust layout manually
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)

plt.title('Confusion Matrix')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
model.save("../sih_leaf_cnn.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
